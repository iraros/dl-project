# %%
import labeler
import utils
import IPython.display

miss_path = '/home/ira/Desktop/inception-trial/datas/UrbanSound8K/training results/wave forms/missclassified.txt'

image = 'datas/UrbanSound8K/wave_forms/street_music/77769-9-0-17.wav.png'

result_string = labeler.get_labels_string(image, model_name='wave_forms', label_name='wave_forms')

print('correct class: ' + utils.path2class(image))
print('classification: \n' + result_string)
# Out:
# correct class: street_music
# classification:
# 0.2974 car horn
# 0.2911 children playing
# 0.1696 drilling
# 0.1218 siren
# 0.0798 street music
# 0.0205 dog bark
# 0.0122 air conditioner
# 0.0038 jackhammer
# 0.0028 engine idling
# 0.0011 gun shot

# %%
print('the image:')
IPython.display.Image(image)
# Out:
# the image:

# %%
path = utils.path2wav_path('77769-9-0-17.wav')
print('the sound:')

IPython.display.Audio(path)
# Out:
# the sound:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

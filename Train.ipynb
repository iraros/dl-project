# %%
# !python retrain.py --image_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/spectrograms \
--bottleneck_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/bottlenecks/spectrograms/ \
--output_graph /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_graphs/spectrograms.pb \
--output_labels /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_labels/spectrograms.txt \
--how_many_training_steps=100000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0425 06:12:06.163158 140421520656192 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0425 06:12:06.302908 140421520656192 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0425 06:12:06.351799 140421520656192 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0425 06:12:06.377098 140421520656192 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0425 06:12:06.478812 140421520656192 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0425 06:12:06.537717 140421520656192 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...

# %%
# !python retrain.py --image_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/features_for_cross_fold_evaluation/spectrograms/evaluation_on_fold10/training_all_folds_but_fold10 \
--bottleneck_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/bottlenecks/spectrograms \
--output_graph /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/features_for_cross_fold_evaluation/spectrograms/evaluation_on_fold10/model_for_evaluating_fold10.pb \
--output_labels /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/features_for_cross_fold_evaluation/spectrograms/evaluation_on_fold10/model_for_evaluating_fold10.txt \
--how_many_training_steps=10000 \
--testing_percentage 1 \
--test_batch_size 1 \
--validation_percentage 1 \
--validation_batch_size 1

import IPython.display
siren_path = '/home/ira/Desktop/dl_project/datas/UrbanSound8K/fold1 split by class/siren/43806-8-0-0.wav'
IPython.display.Audio(siren_path, autoplay=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0425 05:07:52.835731 140349107160896 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0425 05:07:53.033061 140349107160896 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0425 05:07:53.080448 140349107160896 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0425 05:07:53.111527 140349107160896 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0425 05:07:53.158428 140349107160896 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0425 05:07:53.213071 140349107160896 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...

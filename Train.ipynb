# %%
# !python retrain.py --image_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/small_sample \
--bottleneck_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/bottlenecks/small_sample/ \
--output_graph /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_graphs/small_sample.pb \
--output_labels /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_labels/small_sample.txt \
--how_many_training_steps=10000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0423 13:46:02.348007 140398833321792 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0423 13:46:02.361848 140398833321792 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0423 13:46:02.369163 140398833321792 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0423 13:46:02.381073 140398833321792 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0423 13:46:02.389938 140398833321792 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0423 13:46:02.406913 140398833321792 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...

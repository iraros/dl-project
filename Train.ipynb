# %%
# !python retrain.py --print_misclassified_test_images \
--image_dir datas/UrbanSound8K/image_features/non_log_spectrogram \
--bottleneck_dir datas/UrbanSound8K/bottlenecks/non_log_spectrogram/ \
--output_graph datas/UrbanSound8K/output_graphs/non_log_spectrogram.pb \
--output_labels datas/UrbanSound8K/output_labels/non_log_spectrogram.txt \
--how_many_training_steps=8000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0421 15:42:33.268379 140000231368512 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0421 15:42:33.389836 140000231368512 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0421 15:42:33.421185 140000231368512 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0421 15:42:33.445845 140000231368512 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0421 15:42:33.475442 140000231368512 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0421 15:42:33.508245 140000231368512 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...

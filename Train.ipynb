# %%
# !python retrain.py --image_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/spectrograms \
--bottleneck_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/bottlenecks/spectrograms/ \
--output_graph /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_graphs/spectrograms.pb \
--output_labels /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_labels/spectrograms.txt \
--how_many_training_steps=10000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0424 18:11:23.114495 140399332099904 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0424 18:11:23.288500 140399332099904 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0424 18:11:23.341551 140399332099904 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0424 18:11:23.363172 140399332099904 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0424 18:11:23.418235 140399332099904 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0424 18:11:23.491266 140399332099904 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...

# %%
# !python retrain.py --image_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/features_for_cross_fold_evaluation/spectrograms/evaluation_on_fold6/training_all_folds_but_fold6 \
--bottleneck_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/bottlenecks/spectrograms \
--output_graph /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/features_for_cross_fold_evaluation/spectrograms/evaluation_on_fold6/model_for_evaluating_fold6.pb \
--output_labels /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/features_for_cross_fold_evaluation/spectrograms/evaluation_on_fold6/model_for_evaluating_fold6.txt \
--how_many_training_steps=10000 \
--testing_percentage 1 \
--test_batch_size 1 \
--validation_percentage 1 \
--validation_batch_size 1
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0425 02:55:36.442473 140051325646656 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0425 02:55:36.613319 140051325646656 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0425 02:55:36.666537 140051325646656 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0425 02:55:36.693696 140051325646656 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0425 02:55:36.746029 140051325646656 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0425 02:55:36.793879 140051325646656 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...

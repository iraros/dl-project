# %%
# !python retrain.py --image_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/image_features/double_spectrogram_and_wav_RGBA \
--bottleneck_dir /home/ira/Desktop/dl_project/datas/UrbanSound8K/bottlenecks/double_spectrogram_and_wav_RGBA/ \
--output_graph /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_graphs/double_spectrogram_and_wav_RGBA.pb \
--output_labels /home/ira/Desktop/dl_project/datas/UrbanSound8K/output_labels/double_spectrogram_and_wav_RGBA.txt \
--how_many_training_steps=10000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0424 13:14:43.251763 139849020540736 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'air_conditioner'
# I0424 13:14:43.364574 139849020540736 retrain.py:185] Looking for images in 'air_conditioner'
# INFO:tensorflow:Looking for images in 'car_horn'
# I0424 13:14:43.399059 139849020540736 retrain.py:185] Looking for images in 'car_horn'
# INFO:tensorflow:Looking for images in 'children_playing'
# I0424 13:14:43.420835 139849020540736 retrain.py:185] Looking for images in 'children_playing'
# INFO:tensorflow:Looking for images in 'dog_bark'
# I0424 13:14:43.457552 139849020540736 retrain.py:185] Looking for images in 'dog_bark'
# INFO:tensorflow:Looking for images in 'drilling'
# I0424 13:14:43.493026 139849020540736 retrain.py:185] Looking for images in 'drilling'
# INFO:tensorflow:Looking for images in 'engine_idling'
# ...
